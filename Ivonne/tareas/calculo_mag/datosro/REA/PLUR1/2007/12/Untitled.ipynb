# %%
from obspy import read
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
st1 = read("2007-12-04-0812-15S.LD3___001_S__1Z")

# %%
z1 = st1[0];

# %%
r = 0.8255e14

# %%
z1.data = z1.data/r;

# %%
z1.plot()
