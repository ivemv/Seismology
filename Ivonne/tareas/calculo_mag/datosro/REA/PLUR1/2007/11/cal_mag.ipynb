# %%
from obspy import read
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
st1110 = read("2007-11-10-2054-22S.LD3___001_S__1Z")

# %%
z = st1110[0];

# %%
r = 0.8255e14

# %%
z.data = z.data/r;

# %%
z.plot()

# %%
st2 = read("2007-11-10-2054-23S.LD5___001_S__1Z")

# %%
z2 = st2[0];

# %%
z2.data = z2.data/r;

# %%
z2.plot()

# %%
st3 = read("2007-11-10-2054-24S.LD2___001_S__1Z")

# %%
z3 = st3[0];

# %%
z3.data = z3.data/r;

# %%
z3.plot()
