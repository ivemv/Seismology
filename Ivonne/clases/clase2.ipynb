# %% [markdown]
# ### Sream vs trace

# %%
from obspy import read, UTCDateTime
import numpy as np

# %%
st = read()

# %%
st
# Out:
# 3 Trace(s) in Stream:
# BW.RJOB..EHZ | 2009-08-24T00:20:03.000000Z - 2009-08-24T00:20:32.990000Z | 100.0 Hz, 3000 samples
# BW.RJOB..EHN | 2009-08-24T00:20:03.000000Z - 2009-08-24T00:20:32.990000Z | 100.0 Hz, 3000 samples
# BW.RJOB..EHE | 2009-08-24T00:20:03.000000Z - 2009-08-24T00:20:32.990000Z | 100.0 Hz, 3000 samples

# %%
tr = st[0]

# %%
tr
# Out:
# BW.RJOB..EHZ | 2009-08-24T00:20:03.000000Z - 2009-08-24T00:20:32.990000Z | 100.0 Hz, 3000 samples

# %%
type(tr)
# Out:
# obspy.core.trace.Trace

# %%
type(st)
# Out:
# obspy.core.stream.Stream

# %%
tr.stats
# Out:
#          network: BW
#          station: RJOB
#         location:
#          channel: EHZ
#        starttime: 2009-08-24T00:20:03.000000Z
#          endtime: 2009-08-24T00:20:32.990000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 3000
#            calib: 1.0
#     back_azimuth: 100.0
#      inclination: 30.0
#         response: Channel Response
# 	From M/S (Velocity in Meters Per Second) to COUNTS (Digital Counts)
# 	Overall Sensitivity: 2.5168e+09 defined at 0.020 Hz
# 	4 stages:
# 		Stage 1: PolesZerosResponseStage from M/S to V, gain: 1500
# 		Stage 2: CoefficientsTypeResponseStage from V to COUNTS, gain: 1.67785e+06
# 		Stage 3: FIRResponseStage from COUNTS to COUNTS, gain: 1
# 		Stage 4: FIRResponseStage from COUNTS to COUNTS, gain: 1

# %%
st.plot()

# %%
tr.plot()

# %%
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = tr.data

# %%
type(data)
# Out:
# numpy.ndarray

# %%
plt.plot(data)

# %%
from obspy.clients.earthworm.client import Client

# %%
clien = Client("132.247.71.87",16071)

# %%
clien.get_availability()
# Out:
# [('MG',
#   'JRQG',
#   '--',
#   'HHE',
#   2018-02-09T01:06:21.890001Z,
#   2018-02-14T15:52:09.980000Z),
#  ('MG',
#   'JRQG',
#   '--',
#   'HHN',
#   2018-02-09T06:07:24.420000Z,
#   2018-02-14T15:52:09.360000Z),
#  ('MG',
#   'JRQG',
#   '--',
#   'HHZ',
#   2018-02-09T18:22:11.369998Z,
#   2018-02-14T15:52:09.090000Z),
#  ('MG',
#   'JRQG',
#   '--',
#   'HLE',
#   2018-02-07T14:50:06.440000Z,
#   2018-02-14T15:52:08.450000Z),
#  ('MG',
#   'JRQG',
#   '--',
#   'HLN',
#   2018-02-07T18:05:28.290000Z,
#   2018-02-14T15:52:06.820000Z),
#  ('MG',
#   'JRQG',
#   '--',
#   'HLZ',
#   2018-02-08T06:47:26.170000Z,
#   2018-02-14T15:52:09.170000Z)]

# %%
t1 = UTCDateTime(2018,2,9,14,6,0)

# %%
st = clien.get_waveforms("MG","JRQG","--","H?",t1,t1+1200)
# Out:
# read_wave_server_v returned flag FN - requested tank not found
# read_wave_server_v returned flag FN - requested tank not found
# read_wave_server_v returned flag FN - requested tank not found

# %%
# ?clien.get_waveforms

# %%
st
# Out:
# 0 Trace(s) in Stream:

# %%
t1
# Out:
# 2018-02-09T14:06:00.000000Z
