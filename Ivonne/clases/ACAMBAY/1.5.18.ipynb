# %%
from obspy import read, UTCDateTime

# %%
import matplotlib.pyplot as plt

# %%
t1 = UTCDateTime(2018,5,1,18,33)

# %%
t2 = UTCDateTime(2018,5,1,18,36)

# %%
ac = read("MX.ACIG..BHZ.D.2018.121")

# %%
ac.trim(t1,t2)
# Out:
# 1 Trace(s) in Stream:
# MX.ACIG..BHZ | 2018-05-01T18:33:00.005000Z - 2018-05-01T18:36:00.005000Z | 20.0 Hz, 3601 samples

# %%
ac.plot()

# %%
ac.filter("bandpass",freqmin=1,freqmax=10)
# Out:
# /home/marv/anaconda3/lib/python3.6/site-packages/obspy/signal/filter.py:67: UserWarning: Selected high corner frequency (10) of bandpass is at or above Nyquist (10.0). Applying a high-pass instead.
#   warnings.warn(msg)
# 1 Trace(s) in Stream:
# MX.ACIG..BHZ | 2018-05-01T18:33:00.005000Z - 2018-05-01T18:36:00.005000Z | 20.0 Hz, 3601 samples

# %%
ac.plot()
