# %%
import obspy
from obspy.clients.fdsn import Client
from obspy import UTCDateTime

# %%
from obspy import read

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 12, 8

# %%
t2 = UTCDateTime(2018,1,1,0,0,0)
t2f = UTCDateTime(2018,5,20,0,0,0)

# %%
client=Client("IRIS")

# %%
cat = client.get_events(starttime=t2,endtime=t2f,minmagnitude=6.5)

# %%
print(cat.__str__(print_all=True))
# Out:
# 12 Event(s) in Catalog:
# 2018-05-04T22:32:54.370000Z | +19.313, -154.998 | 6.9 Mw
# 2018-04-02T13:40:34.840000Z | -20.659,  -63.006 | 6.8 Mww
# 2018-03-29T21:25:36.860000Z |  -5.495, +151.507 | 6.9 mww
# 2018-03-26T09:51:00.700000Z |  -5.462, +151.396 | 6.6 mww
# 2018-03-08T17:39:51.130000Z |  -4.385, +153.187 | 6.8 mww
# 2018-03-06T14:13:06.020000Z |  -6.293, +142.613 | 6.7 Mww
# 2018-02-25T17:44:44.070000Z |  -6.053, +142.770 | 7.5 mww
# 2018-02-16T23:39:39.700000Z | +16.389,  -97.979 | 7.2 mww
# 2018-01-28T16:03:03.970000Z | -53.062,   +9.684 | 6.6 Mww
# 2018-01-23T09:31:42.940000Z | +56.046, -149.073 | 7.9 Mww
# 2018-01-14T09:18:45.540000Z | -15.759,  -74.710 | 7.1 mww
# 2018-01-10T02:51:31.860000Z | +17.474,  -83.519 | 7.5 mww

# %%
cat.plot()
# Out:
# /home/marv/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %%
cmt = obspy.read_events("qcmt.ndk")

# %%
print(cmt)
# Out:
# 620 Event(s) in Catalog:
# 2017-01-01T14:12:14.600000Z |  +3.640, +128.640 | 5.5 Mwc
# 2017-01-01T14:13:38.600000Z |  +3.690, +128.680 | 5.53 Mwc
# ...
# 2018-05-22T00:26:11.000000Z | +12.730, +145.540 | 5.68 Mwc
# 2018-05-22T03:51:29.500000Z | +19.070, -155.270 | 4.91 Mwc
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
#print(cmt.__str__(print_all=True))

# %%
cmt2 = cmt.filter("magnitude > 6.5")

# %%
print(cmt2)
# Out:
# 42 Event(s) in Catalog:
# 2017-01-03T21:52:38.200000Z | -19.310, +176.020 | 6.93 Mwc
# 2017-01-10T06:13:54.000000Z |  +4.500, +122.810 | 7.27 Mwc
# ...
# 2018-04-02T13:40:42.500000Z | -20.640,  -62.900 | 6.83 Mwc
# 2018-05-04T22:33:10.500000Z | +19.120, -154.710 | 6.89 Mwc
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
cmt2.plot()
# Out:
# /home/marv/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %%
cmt3 = cmt2.filter("time > 2018-01-01", "time < 2018-05-22")

# %%
print(cmt3)
# Out:
# 12 Event(s) in Catalog:
# 2018-01-10T02:51:42.200000Z | +17.560,  -83.900 | 7.53 Mwc
# 2018-01-14T09:18:52.800000Z | -15.980,  -74.860 | 7.12 Mwc
# ...
# 2018-04-02T13:40:42.500000Z | -20.640,  -62.900 | 6.83 Mwc
# 2018-05-04T22:33:10.500000Z | +19.120, -154.710 | 6.89 Mwc
# To see all events call 'print(CatalogObject.__str__(print_all=True))'

# %%
cmt4 = cmt3.filter("latitude < 5.4", "latitude > -10.51", "longitude > 136.26", "longitude < 160.95 ")

# %%
print(cmt4)
# Out:
# 5 Event(s) in Catalog:
# 2018-02-25T17:45:08.500000Z |  -6.280, +143.020 | 7.46 Mwc
# 2018-03-06T14:13:23.200000Z |  -6.400, +142.560 | 6.68 Mwc
# 2018-03-08T17:39:59.000000Z |  -4.340, +153.290 | 6.78 Mwc
# 2018-03-26T09:51:06.900000Z |  -5.680, +151.400 | 6.7 Mwc
# 2018-03-29T21:25:45.000000Z |  -5.670, +151.640 | 6.9 Mwc

# %%
t1 = UTCDateTime(2018,2,25,17,44,0)
t2 = UTCDateTime(2018,3,6,14,13,22)
t3 = UTCDateTime(2018,3,8,17,38,0)
t4 = UTCDateTime(2018,3,26,9,51,0)
t5 = UTCDateTime(2018,3,29,21,25,0)

# %%
cmt4.plot(projection="local")
# Out:
# /home/marv/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1708: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   limb = ax.axesPatch
# /home/marv/anaconda3/lib/python3.6/site-packages/mpl_toolkits/basemap/__init__.py:1711: MatplotlibDeprecationWarning: The axesPatch function was deprecated in version 2.1. Use Axes.patch instead.
#   if limb is not ax.axesPatch:

# %%
e1 = client.get_waveforms("MG","JRQG","","HH*",t1,t1+6000)

# %%
#e1.plot()

# %%
e29 = read("UC.MNGR.20180225.mseed")

# %%
e29.merge()
# Out:
# 4 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-02-25T00:00:23.940000Z - 2018-02-25T23:59:29.530000Z | 100.0 Hz, 8634560 samples (masked)
# UC.MNGR..HHE | 2018-02-25T00:00:00.000000Z - 2018-02-25T23:59:32.330000Z | 100.0 Hz, 8637234 samples (masked)
# UC.MNGR..HHN | 2018-02-25T00:00:00.000000Z - 2018-02-25T23:59:59.990000Z | 100.0 Hz, 8640000 samples
# UC.MNGR..HHZ | 2018-02-25T00:00:00.000000Z - 2018-02-25T23:59:59.990000Z | 100.0 Hz, 8640000 samples

# %%
e29.plot()

# %%
e29c = e29.copy()

# %%
e29c.trim(t1,t1+10800)
# Out:
# 4 Trace(s) in Stream:
# UC.MNGR..BDF | 2018-02-25T17:44:00.000000Z - 2018-02-25T20:44:00.000000Z | 100.0 Hz, 1080001 samples
# UC.MNGR..HHE | 2018-02-25T17:44:00.000000Z - 2018-02-25T20:44:00.000000Z | 100.0 Hz, 1080001 samples
# UC.MNGR..HHN | 2018-02-25T17:44:00.000000Z - 2018-02-25T20:44:00.000000Z | 100.0 Hz, 1080001 samples
# UC.MNGR..HHZ | 2018-02-25T17:44:00.000000Z - 2018-02-25T20:44:00.000000Z | 100.0 Hz, 1080001 samples

# %%
e29c.plot()

# %%
pwd
# Out:
# '/home/marv/Seismology/Ivonne/clases'

# %%
#lista de eventos de magnitud >6.5 desde el 1 enero GMT
#plot ,¿cuántos caen en Papúa Nva G?
#trazas de las estaciones en VdC, inst. recientes
#efectos de tren de ondas armónicos (bajas frec; eventos telesísmicos)
