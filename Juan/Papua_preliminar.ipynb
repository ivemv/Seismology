# %%
from obspy import read, UTCDateTime
from obspy.clients.fdsn import Client

# %%
cli = Client("IRIS")

# %%
t1= UTCDateTime(2018,2,25,17,43,0)

#2018-02-25 17:44:44

# %%
port=cli.get_waveforms("IU", "PMG", "**", "HH*", t1, t1+5007, attach_response="true")
#Port Moresby, Papua New Guinea. Dist: 5.44°

# %%
port
# Out:
# 3 Trace(s) in Stream:
# IU.PMG.10.HH1 | 2018-02-25T17:45:01.658393Z - 2018-02-25T17:59:01.908393Z | 100.0 Hz, 84026 samples
# IU.PMG.10.HH2 | 2018-02-25T17:44:57.958393Z - 2018-02-25T17:59:01.978393Z | 100.0 Hz, 84403 samples
# IU.PMG.10.HHZ | 2018-02-25T17:44:53.458393Z - 2018-02-25T17:59:01.948393Z | 100.0 Hz, 84850 samples

# %%
portz=port[2]

# %%
portz.plot()

# %%
portz2 = portz.copy()

# %%
portz2.remove_response()
# Out:
# IU.PMG.10.HHZ | 2018-02-25T17:44:53.458393Z - 2018-02-25T17:59:01.948393Z | 100.0 Hz, 84850 samples

# %%
portz2.plot()

# %%
juri=cli.get_waveforms("MG", "JRQG", "**", "HH*", t1+60, t1+5000, attach_response="true")

# %%
juri
# Out:
# 3 Trace(s) in Stream:
# MG.JRQG..HHE | 2018-02-25T17:44:00.000000Z - 2018-02-25T19:06:20.000000Z | 100.0 Hz, 494001 samples
# MG.JRQG..HHN | 2018-02-25T17:44:00.000000Z - 2018-02-25T19:06:20.000000Z | 100.0 Hz, 494001 samples
# MG.JRQG..HHZ | 2018-02-25T17:44:00.000000Z - 2018-02-25T19:06:20.000000Z | 100.0 Hz, 494001 samples

# %%
juriz=juri[2]

# %%
juriz.plot()

# %%
juriz2 = juriz.copy()

# %%
juriz2.remove_response()
# Out:
# MG.JRQG..HHZ | 2018-02-25T17:44:00.000000Z - 2018-02-25T19:06:20.000000Z | 100.0 Hz, 494001 samples

# %%
juriz2.plot()

# %%
st = Stream(traces=[portz,juriz])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-4c37191ea63e> in <module>()
# ----> 1 st = Stream(traces=[portz,juriz])
#
# NameError: name 'Stream' is not defined

# %%
portz.plot()
juriz.plot()

# %% [raw]
# #Cada cliente tiene atributos diferentes
#
# #Metadatos
# #met=get.channelmetadata
